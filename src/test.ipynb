# %%
import os
from collection_loader import CollectionLoader
from embeddings import UpstageEmbedding
from dotenv import load_dotenv
from utils import find_matching_collections

vector_path = "src/vector_db"
collections = []
query = "외상후 스트레스 장애(PTSD)를 보장하는 보험은?"
loader = CollectionLoader(vector_path, UpstageEmbedding)

available_collections = [
        d
        for d in os.listdir(loader.base_path)
        if os.path.isdir(os.path.join(loader.base_path, d))
    ]
print(f"사용 가능한 컬렉션: {available_collections}")

# 요청된 컬렉션이 있거나 쿼리 기반으로 컬렉션을 찾습니다
use_collections = (
    collections
    if collections
    else find_matching_collections(query, available_collections)
)
print(f"사용할 컬렉션: {use_collections}")

# 찾은 컬렉션 로드
for collection_name in use_collections:
    loader.load_collection(collection_name)
# Out:
# 사용 가능한 컬렉션: ['LotteSonBo_YakMuLDeo25011220250101', 'Samsung_YakMu2404103NapHae20250113', 'MGSonBo_YakMuWon2404Se20250101', 'HanWha_YakHan20250201', 'Meritz_YakMu220250113', 'DBSonBo_YakMu20250123', 'KB_YakKSeHaeMu250120250214', 'HaNa_YakMuHaGaengPyo20250101', 'Heung_YakMu250220250205', 'HyunDai_YakMuSeH1Il2Nap20250213', 'NH_YakMuN5250120250101']
#
# -------- 컬렉션 매칭 시작 --------
# 질문: '외상후 스트레스 장애(PTSD)를 보장하는 보험은?'
# 사용 가능한 컬렉션: ['LotteSonBo_YakMuLDeo25011220250101', 'Samsung_YakMu2404103NapHae20250113', 'MGSonBo_YakMuWon2404Se20250101', 'HanWha_YakHan20250201', 'Meritz_YakMu220250113', 'DBSonBo_YakMu20250123', 'KB_YakKSeHaeMu250120250214', 'HaNa_YakMuHaGaengPyo20250101', 'Heung_YakMu250220250205', 'HyunDai_YakMuSeH1Il2Nap20250213', 'NH_YakMuN5250120250101']
# 기본 컬렉션 매칭: LotteSonBo_YakMuLDeo25011220250101
# 기본 컬렉션 매칭: Samsung_YakMu2404103NapHae20250113
# 기본 컬렉션 매칭: MGSonBo_YakMuWon2404Se20250101
# 기본 컬렉션 매칭: HanWha_YakHan20250201
# 기본 컬렉션 매칭: Meritz_YakMu220250113
# 기본 컬렉션 매칭: DBSonBo_YakMu20250123
# 기본 컬렉션 매칭: KB_YakKSeHaeMu250120250214
# 기본 컬렉션 매칭: HaNa_YakMuHaGaengPyo20250101
# 기본 컬렉션 매칭: Heung_YakMu250220250205
# 기본 컬렉션 매칭: HyunDai_YakMuSeH1Il2Nap20250213
# 기본 컬렉션 매칭: NH_YakMuN5250120250101
# 최종 매칭된 컬렉션: ['NH_YakMuN5250120250101', 'DBSonBo_YakMu20250123', 'HyunDai_YakMuSeH1Il2Nap20250213', 'Samsung_YakMu2404103NapHae20250113', 'HaNa_YakMuHaGaengPyo20250101', 'HanWha_YakHan20250201', 'Heung_YakMu250220250205', 'MGSonBo_YakMuWon2404Se20250101', 'LotteSonBo_YakMuLDeo25011220250101', 'Meritz_YakMu220250113', 'KB_YakKSeHaeMu250120250214']
# -------- 컬렉션 매칭 완료 --------
#
# 사용할 컬렉션: ['NH_YakMuN5250120250101', 'DBSonBo_YakMu20250123', 'HyunDai_YakMuSeH1Il2Nap20250213', 'Samsung_YakMu2404103NapHae20250113', 'HaNa_YakMuHaGaengPyo20250101', 'HanWha_YakHan20250201', 'Heung_YakMu250220250205', 'MGSonBo_YakMuWon2404Se20250101', 'LotteSonBo_YakMuLDeo25011220250101', 'Meritz_YakMu220250113', 'KB_YakKSeHaeMu250120250214']
# 컬렉션 로드 요청 받음: 'NH_YakMuN5250120250101'
# 자동 변환: 'NH_YakMuN5250120250101' -> 'NH_YakMuN5250120250101'
# 컬렉션 로드 시도: 'NH_YakMuN5250120250101' -> 'NH_YakMuN5250120250101'
# LangChain을 통해 컬렉션 로드 시도: '/Users/hyerim/sessac/rag/src/vector_db/NH_YakMuN5250120250101'
# 로드된 인덱스 타입: IndexFlatL2
# 인덱스 차원: 4096, 벡터 수: 4696
# 메타데이터가 리스트 형식입니다. 딕셔너리로 변환합니다.
# 리스트를 딕셔너리로 변환 완료: 4696개 항목
# 메타데이터 항목 수: 4696
# 메타데이터 샘플 키: ['0', '1', '2', '3', '4']
# 메타데이터 키 타입: [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]
# 메타데이터 첫 항목: dict_keys(['source', 'text'])
# NH_YakMuN5250120250101 컬렉션 로드 완료: 4696개 벡터
# 컬렉션 로드 요청 받음: 'DBSonBo_YakMu20250123'
# 자동 변환: 'DBSonBo_YakMu20250123' -> 'DBSonBo_YakMu20250123'
# 컬렉션 로드 시도: 'DBSonBo_YakMu20250123' -> 'DBSonBo_YakMu20250123'
# LangChain을 통해 컬렉션 로드 시도: '/Users/hyerim/sessac/rag/src/vector_db/DBSonBo_YakMu20250123'
# 로드된 인덱스 타입: IndexFlatL2
# 인덱스 차원: 4096, 벡터 수: 6197
# 메타데이터가 리스트 형식입니다. 딕셔너리로 변환합니다.
# 리스트를 딕셔너리로 변환 완료: 6197개 항목
# 메타데이터 항목 수: 6197
# 메타데이터 샘플 키: ['0', '1', '2', '3', '4']
# 메타데이터 키 타입: [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]
# 메타데이터 첫 항목: dict_keys(['Header 1', 'source', 'text'])
# DBSonBo_YakMu20250123 컬렉션 로드 완료: 6197개 벡터
# 컬렉션 로드 요청 받음: 'HyunDai_YakMuSeH1Il2Nap20250213'
# 자동 변환: 'HyunDai_YakMuSeH1Il2Nap20250213' -> 'HyunDai_YakMuSeH1Il2Nap20250213'
# 컬렉션 로드 시도: 'HyunDai_YakMuSeH1Il2Nap20250213' -> 'HyunDai_YakMuSeH1Il2Nap20250213'
# LangChain을 통해 컬렉션 로드 시도: '/Users/hyerim/sessac/rag/src/vector_db/HyunDai_YakMuSeH1Il2Nap20250213'
# 로드된 인덱스 타입: IndexFlatL2
# 인덱스 차원: 4096, 벡터 수: 5035
# 메타데이터가 리스트 형식입니다. 딕셔너리로 변환합니다.
# 리스트를 딕셔너리로 변환 완료: 5035개 항목
# 메타데이터 항목 수: 5035
# 메타데이터 샘플 키: ['0', '1', '2', '3', '4']
# 메타데이터 키 타입: [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]
# 메타데이터 첫 항목: dict_keys(['source', 'text'])
# HyunDai_YakMuSeH1Il2Nap20250213 컬렉션 로드 완료: 5035개 벡터
# 컬렉션 로드 요청 받음: 'Samsung_YakMu2404103NapHae20250113'
# 자동 변환: 'Samsung_YakMu2404103NapHae20250113' -> 'Samsung_YakMu2404103NapHae20250113'
# 컬렉션 로드 시도: 'Samsung_YakMu2404103NapHae20250113' -> 'Samsung_YakMu2404103NapHae20250113'
# LangChain을 통해 컬렉션 로드 시도: '/Users/hyerim/sessac/rag/src/vector_db/Samsung_YakMu2404103NapHae20250113'
# 로드된 인덱스 타입: IndexFlatL2
# 인덱스 차원: 4096, 벡터 수: 7606
# 메타데이터가 리스트 형식입니다. 딕셔너리로 변환합니다.
# 리스트를 딕셔너리로 변환 완료: 7606개 항목
# 메타데이터 항목 수: 7606
# 메타데이터 샘플 키: ['0', '1', '2', '3', '4']
# 메타데이터 키 타입: [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]
# 메타데이터 첫 항목: dict_keys(['Header 1', 'source', 'text'])
# Samsung_YakMu2404103NapHae20250113 컬렉션 로드 완료: 7606개 벡터
# 컬렉션 로드 요청 받음: 'HaNa_YakMuHaGaengPyo20250101'
# 자동 변환: 'HaNa_YakMuHaGaengPyo20250101' -> 'HaNa_YakMuHaGaengPyo20250101'
# 컬렉션 로드 시도: 'HaNa_YakMuHaGaengPyo20250101' -> 'HaNa_YakMuHaGaengPyo20250101'
# LangChain을 통해 컬렉션 로드 시도: '/Users/hyerim/sessac/rag/src/vector_db/HaNa_YakMuHaGaengPyo20250101'
# 로드된 인덱스 타입: IndexFlatL2
# 인덱스 차원: 4096, 벡터 수: 2717
# 메타데이터가 리스트 형식입니다. 딕셔너리로 변환합니다.
# 리스트를 딕셔너리로 변환 완료: 2717개 항목
# 메타데이터 항목 수: 2717
# 메타데이터 샘플 키: ['0', '1', '2', '3', '4']
# 메타데이터 키 타입: [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]
# 메타데이터 첫 항목: dict_keys(['Header 1', 'source', 'text'])
# HaNa_YakMuHaGaengPyo20250101 컬렉션 로드 완료: 2717개 벡터
# 컬렉션 로드 요청 받음: 'HanWha_YakHan20250201'
# 자동 변환: 'HanWha_YakHan20250201' -> 'HanWha_YakHan20250201'
# 컬렉션 로드 시도: 'HanWha_YakHan20250201' -> 'HanWha_YakHan20250201'
# LangChain을 통해 컬렉션 로드 시도: '/Users/hyerim/sessac/rag/src/vector_db/HanWha_YakHan20250201'
# 로드된 인덱스 타입: IndexFlatL2
# 인덱스 차원: 4096, 벡터 수: 3717
# 메타데이터가 리스트 형식입니다. 딕셔너리로 변환합니다.
# 리스트를 딕셔너리로 변환 완료: 3717개 항목
# 메타데이터 항목 수: 3717
# 메타데이터 샘플 키: ['0', '1', '2', '3', '4']
# 메타데이터 키 타입: [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]
# 메타데이터 첫 항목: dict_keys(['Header 1', 'source', 'text'])
# HanWha_YakHan20250201 컬렉션 로드 완료: 3717개 벡터
# 컬렉션 로드 요청 받음: 'Heung_YakMu250220250205'
# 자동 변환: 'Heung_YakMu250220250205' -> 'Heung_YakMu250220250205'
# 컬렉션 로드 시도: 'Heung_YakMu250220250205' -> 'Heung_YakMu250220250205'
# LangChain을 통해 컬렉션 로드 시도: '/Users/hyerim/sessac/rag/src/vector_db/Heung_YakMu250220250205'
# 로드된 인덱스 타입: IndexFlatL2
# 인덱스 차원: 4096, 벡터 수: 5603
# 메타데이터가 리스트 형식입니다. 딕셔너리로 변환합니다.
# 리스트를 딕셔너리로 변환 완료: 5603개 항목
# 메타데이터 항목 수: 5603
# 메타데이터 샘플 키: ['0', '1', '2', '3', '4']
# 메타데이터 키 타입: [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]
# 메타데이터 첫 항목: dict_keys(['Header 1', 'source', 'text'])
# Heung_YakMu250220250205 컬렉션 로드 완료: 5603개 벡터
# 컬렉션 로드 요청 받음: 'MGSonBo_YakMuWon2404Se20250101'
# 자동 변환: 'MGSonBo_YakMuWon2404Se20250101' -> 'MGSonBo_YakMuWon2404Se20250101'
# 컬렉션 로드 시도: 'MGSonBo_YakMuWon2404Se20250101' -> 'MGSonBo_YakMuWon2404Se20250101'
# LangChain을 통해 컬렉션 로드 시도: '/Users/hyerim/sessac/rag/src/vector_db/MGSonBo_YakMuWon2404Se20250101'
# 로드된 인덱스 타입: IndexFlatL2
# 인덱스 차원: 4096, 벡터 수: 3725
# 메타데이터가 리스트 형식입니다. 딕셔너리로 변환합니다.
# 리스트를 딕셔너리로 변환 완료: 3725개 항목
# 메타데이터 항목 수: 3725
# 메타데이터 샘플 키: ['0', '1', '2', '3', '4']
# 메타데이터 키 타입: [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]
# 메타데이터 첫 항목: dict_keys(['Header 1', 'source', 'text'])
# MGSonBo_YakMuWon2404Se20250101 컬렉션 로드 완료: 3725개 벡터
# 컬렉션 로드 요청 받음: 'LotteSonBo_YakMuLDeo25011220250101'
# 자동 변환: 'LotteSonBo_YakMuLDeo25011220250101' -> 'LotteSonBo_YakMuLDeo25011220250101'
# 컬렉션 로드 시도: 'LotteSonBo_YakMuLDeo25011220250101' -> 'LotteSonBo_YakMuLDeo25011220250101'
# LangChain을 통해 컬렉션 로드 시도: '/Users/hyerim/sessac/rag/src/vector_db/LotteSonBo_YakMuLDeo25011220250101'
# 로드된 인덱스 타입: IndexFlatL2
# 인덱스 차원: 4096, 벡터 수: 3854
# 메타데이터가 리스트 형식입니다. 딕셔너리로 변환합니다.
# 리스트를 딕셔너리로 변환 완료: 3854개 항목
# 메타데이터 항목 수: 3854
# 메타데이터 샘플 키: ['0', '1', '2', '3', '4']
# 메타데이터 키 타입: [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]
# 메타데이터 첫 항목: dict_keys(['Header 1', 'source', 'text'])
# LotteSonBo_YakMuLDeo25011220250101 컬렉션 로드 완료: 3854개 벡터
# 컬렉션 로드 요청 받음: 'Meritz_YakMu220250113'
# 자동 변환: 'Meritz_YakMu220250113' -> 'Meritz_YakMu220250113'
# 컬렉션 로드 시도: 'Meritz_YakMu220250113' -> 'Meritz_YakMu220250113'
# LangChain을 통해 컬렉션 로드 시도: '/Users/hyerim/sessac/rag/src/vector_db/Meritz_YakMu220250113'
# 로드된 인덱스 타입: IndexFlatL2
# 인덱스 차원: 4096, 벡터 수: 6800
# 메타데이터가 리스트 형식입니다. 딕셔너리로 변환합니다.
# 리스트를 딕셔너리로 변환 완료: 6800개 항목
# 메타데이터 항목 수: 6800
# 메타데이터 샘플 키: ['0', '1', '2', '3', '4']
# 메타데이터 키 타입: [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]
# 메타데이터 첫 항목: dict_keys(['source', 'text'])
# Meritz_YakMu220250113 컬렉션 로드 완료: 6800개 벡터
# 컬렉션 로드 요청 받음: 'KB_YakKSeHaeMu250120250214'
# 자동 변환: 'KB_YakKSeHaeMu250120250214' -> 'KB_YakKSeHaeMu250120250214'
# 컬렉션 로드 시도: 'KB_YakKSeHaeMu250120250214' -> 'KB_YakKSeHaeMu250120250214'
# LangChain을 통해 컬렉션 로드 시도: '/Users/hyerim/sessac/rag/src/vector_db/KB_YakKSeHaeMu250120250214'
# 로드된 인덱스 타입: IndexFlatL2
# 인덱스 차원: 4096, 벡터 수: 4429
# 메타데이터가 리스트 형식입니다. 딕셔너리로 변환합니다.
# 리스트를 딕셔너리로 변환 완료: 4429개 항목
# 메타데이터 항목 수: 4429
# 메타데이터 샘플 키: ['0', '1', '2', '3', '4']
# 메타데이터 키 타입: [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>]
# 메타데이터 첫 항목: dict_keys(['Header 1', 'source', 'text'])
# KB_YakKSeHaeMu250120250214 컬렉션 로드 완료: 4429개 벡터
